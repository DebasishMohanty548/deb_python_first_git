# %% [markdown]
# EDA

# %% [markdown]
# packages

# %% [raw]
# -------------------EDA--------------------
# 1) pandas : dataframe or data applications
# 2)numpy : numerical python for math operations
# 3)matplotlib: for visualization (graphs)
# 4)seaborn: for visualization (graphs)
# 5)bokhe: for visualization (graphs)
# 6)plotly: for visualization (graphs)
#
# -------------------ML---------------------
# 7)scikit learn(Sklearn): ML models
# 8)stats:   statistical models
#
# -------data retrival from sql scrapping----------
# 9)sqlite: connect with database
# 10)Beautiful soUp: scrap the data from website
# 11)websocket: scrap
#
# ---------deep learning/computer vision--------
# 12)tensorflow: google
# 13)keras : DL models
# 14)OpenCV: image operations
# 15)pillow(PIL): image operations
# 16)pytorch: facebook
# 17)PRETRAINED MODELS:
# VGG16
# mobilenet
# RESNET
# RCNN
# YOLO
# MASKRCNN
# FASTERCNN
#
# -------------NLP-------------------
# 18)NLTK
# 19)spicy
# 20)Word2vec(how number will convert into vector)
# 21)Glove
# 22)wordcloud
#
# ---------------hugging fae------------------------
# 23)Transformer: BERT(Bidirectional Encoder Representations from Transformers)
#
# -----------------GenAI model--------------------------
# 24)openAI+mocrosoft: GPT MODELS(generative pretrained transformers)
# 25)Google: GEMINI
# 26)AMAZON: Q
# 27) META:MetaAI
# 28) APPLE:APPLE ai
# LLAMA
# GEMMA
# dalle-E
# T5
#
# ------LANGCHAIN---------
# 29)Langchain framework.
#
# --------DEPLOYMENT APPLICATIONS--------
# 30)Flask
# 31)Streamlit
# 32)Django
#
# ----------------MLops-------------------
# 33)MLflow
# 34)Kubeflow
# 35)Azure Ai services: azure packages
# 36)GCP : GCP packages

# %%
import pandas as pd
d=pd.DataFrame([['a',52],['m',5]],columns=['name','age'],index=[1,2])
print(d)
# Out:
#   name  age
# 1    a   52
# 2    m    5

# %%
r=['hi','hello']
c=[5,6]
t=['op','po']
data=zip(r,c)
xi=[i for i in range(1,len(c)+1) ]
do=pd.DataFrame(data,index=xi,columns=['greet','num'])
di=pd.DataFrame(data,index=t,columns=['greet','num'])
do
# Out:
#    greet  num
# 1     hi    5
# 2  hello    6

# %%
dta=[{'a':1,'b':2},{'a':7,'b':5}]
from IPython.display import HTML
d=pd.DataFrame(dta)
print(d)
print('-------')
HTML(d.to_html(index=False))
# Out:
#    a  b
# 0  1  2
# 1  7  5
# -------
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>a</th>
#       <th>b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(d.to_string(index=False))
# Out:
#  a  b
#  1  2
#  7  5

# %%
print(d.to_csv(index=False))
# Out:
# a,b
# 1,2
# 7,5

# %%
# add a new col on existing dataframe

# %%
import pandas as padhy
df=padhy.DataFrame([['abby',52,'bbsr'],['max',25,'hyd'],['mop',29,'mumbai']],columns=['name','age','city'])
df
# Out:
#    name  age    city
# 0  abby   52    bbsr
# 1   max   25     hyd
# 2   mop   29  mumbai

# %%
#if u want to add a new column first check how may rows are there 
# for ex in our existing dataframe we have 3 rows so the new col shoyld have 3 rows
#suppose to create a new col: sal
#make a list of salary

# %%
import pandas as padhy
df=padhy.DataFrame([['abby',52,'bbsr'],['max',25,'hyd'],['mop',29,'mumbai']],columns=['name','age','city'])
sal=[100000,None,3000000]
df['salary']=sal
df
# Out:
#    name  age    city     salary
# 0  abby   52    bbsr   100000.0
# 1   max   25     hyd        NaN
# 2   mop   29  mumbai  3000000.0

# %%
import pandas as p
l1=[i for i in range(1,11)]
l2=[i**2 for i in range(1,11)]
l3=[i**3 for i in range(1,11)]
data=zip(l1,l2,l3)
col=['numbers','square','cube']
d=p.DataFrame(data,columns=col)
print(d.to_string(index=False,justify='center'))
# Out:
#  numbers  square  cube
#     1        1       1
#     2        4       8
#     3        9      27
#     4       16      64
#     5       25     125
#     6       36     216
#     7       49     343
#     8       64     512
#     9       81     729
#    10      100    1000

# %%
d['cube']=[2,2,2,2,2,2,2,2,2,2]
d.rename(index={2:'two'},columns={'cube':'two'},inplace=True)
d.drop(columns=['two'])
df.columns
df.drop(columns=["age"])
# Out:
#    name    city     salary
# 0  abby    bbsr   100000.0
# 1   max     hyd        NaN
# 2   mop  mumbai  3000000.0

# %%
#drop()
#column= which col you wan to drop
#axis= if axis=0= row(default)
#          axis=1 = col
# inplace = it will provide over ride the data frame or not if true it means oerride the dataframe
#or flase means the dataframe still exist but you need to create a new datsaframe
#or flase means the modified dataframe will be available to use when u pprovude new variable to operation

# %%
df.drop('name',axis=1,inplace=True)

# %%
df
# Out:
#    age    city     salary
# 0   52    bbsr   100000.0
# 1   25     hyd        NaN
# 2   29  mumbai  3000000.0

# %%
df.drop(2,axis=0,inplace=True)

# %%
df
# Out:
#    age  city    salary
# 0   52  bbsr  100000.0
# 1   25   hyd       NaN

# %%
import pandas as p
f=p.read_csv("C:\\Users\\debasish\\DS-AI\\N-IT\\datafiles\\Visadataset.csv")
print(f)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
import pandas as p
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
visa_f=p.read_csv(r"C:\Users\debasish\DS-AI\N-IT\datafiles\Visadataset.csv")
visa_f.to_csv(r"C:\Users\debasish\DS-AI\N-IT\datafiles\Visadataset.csv",index=False)
visa_f
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
import pandas as pd
import numpy as n
import matplotlib.pyplot as m
import seaborn as s
path=r"C:\Users\debasish\DS-AI\N-IT\datafiles\bank.csv"
pd.read_csv(path,delimiter=';')
#bank_file.to_csv(p,index=False)
# Out:
#      age,job,marital,education,default,balance,housing,loan,contact,day,month,duration,campaign,pdays,previous,poutcome,y
# 0     30,unemployed,married,primary,no,1787,no,no,ce...
# 1     33,services,married,secondary,no,4789,yes,yes,...
# 2     35,management,single,tertiary,no,1350,yes,no,c...
# 3     30,management,married,tertiary,no,1476,yes,yes...
# 4     59,blue-collar,married,secondary,no,0,yes,no,u...
# ...                                                 ...
# 4516  33,services,married,secondary,no,-333,yes,no,c...
# 4517  57,self-employed,married,tertiary,yes,-3313,ye...
# 4518  57,technician,married,secondary,no,295,no,no,c...
# 4519  28,blue-collar,married,secondary,no,1137,no,no...
# 4520  44,entrepreneur,single,tertiary,no,1136,yes,ye...
#
# [4521 rows x 1 columns]

# %%
import pandas as pd
p=r"C:\Users\debasish\DS-AI\N-IT\datafiles\Salary_data.csv"
sal=pd.read_csv(p)
sal.to_csv(p,index=False)
sal
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
path=r"C:\Users\debasish\DS-AI\N-IT\datafiles\Salary_data.csv"
pd.read_csv(path)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
import pandas as p
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
visa_f=p.read_csv(r"C:\Users\debasish\DS-AI\N-IT\datafiles\Visadataset.csv")
print(visa_f)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_f.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %%
visa_f.tail(10)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25470                     N             2272         1970
# ...

# %%
visa_f.shape
# Out:
# (25480, 12)

# %%
visa_f.size
# Out:
# 305760

# %%
visa_f.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_f.dtypes #provide each col data type...in series output
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_f.dtypes)
# Out:
# pandas.core.series.Series

# %%
len(visa_f)
# Out:
# 25480

# %%
op=visa_f.dtypes
d=dict(op)
lisobj=[]
lisnum=[]
for i,v in d.items():
    if v=='object':
        lisobj.append(i)
    else:
        lisnum.append(i)
print(lisobj)
print(lisnum)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
op=visa_f.dtypes
d=dict(op)
obj=[i for i,v in d.items() if v=='object']
nu=[i for i,v in d.items() if v!='object']
print(obj)
print(nu)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
#we cannot create a dataframe using these two list because they are of unqual length
#if u want to create a dataframe , then wwe need to make two lists of equal length.

# %%
import pandas as pd
col_dataframe=pd.DataFrame(obj,columns=['categorical_col'])
col_dataframe.to_csv('categircal_data_set.csv',index=False)
num_dataframe=pd.DataFrame(nu,columns=['numerical_col'])
num_dataframe.to_csv('numerical_data_set.csv',index=False)

# %%
num=pd.read_csv(r'C:\Users\debasish\DS-AI\N-IT\datafiles\numerical_data_set.csv')
num.dtypes
dictio=dict(visa_f.dtypes)
colu=[keys for keys,val in dictio.items()]
val=[val for keys,val in dictio.items()]
x=pd.DataFrame(zip(colu,val),columns=['category','datatype'])
x.to_csv('datatypes.csv',index=False)
x
# Out:
#                  category datatype
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %%
visa_f.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
dict1={'Names':['A','B','C'],
      'AGE':[1,2,3]}
pd.DataFrame(dict1)
# Out:
#   Names  AGE
# 0     A    1
# 1     B    2
# 2     C    3

# %%
obj
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
nu
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
dict2={}
dict2['col']=colu
dict2['datatypes']=val
pd.DataFrame(dict2)
# Out:
#                       col datatypes
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
visa_f.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_f.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
#isnull gives whether data is present or not
visa_f.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_f.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
visa_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
#first argument=indices
#indies takes value in lists
#it tries to extract the data
#the value we provide represnts col(axis=1) and row(axis=0)
#bydefault axis =0
visa_f.take([0,1,2])
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_f.take([0,1,2],axis=1)#it retrives col values with 3 cols
# Out:
#          case_id continent education_of_employee
# 0         EZYV01      Asia           High School
# 1         EZYV02      Asia              Master's
# 2         EZYV03      Asia            Bachelor's
# 3         EZYV04      Asia            Bachelor's
# 4         EZYV05    Africa              Master's
# ...          ...       ...                   ...
# 25475  EZYV25476      Asia            Bachelor's
# 25476  EZYV25477      Asia           High School
# 25477  EZYV25478      Asia              Master's
# 25478  EZYV25479      Asia              Master's
# 25479  EZYV25480      Asia            Bachelor's
#
# [25480 rows x 3 columns]

# %%
visa_f.take([7,5,2],axis=1)#select 3 cols 2 5 7
# Out:
#       region_of_employment  no_of_employees education_of_employee
# 0                     West            14513           High School
# 1                Northeast             2412              Master's
# 2                     West            44444            Bachelor's
# 3                     West               98            Bachelor's
# 4                    South             1082              Master's
# ...                    ...              ...                   ...
# 25475                South             2601            Bachelor's
# 25476            Northeast             3274           High School
# 25477                South             1121              Master's
# 25478                 West             1918              Master's
# 25479              Midwest             3195            Bachelor's
#
# [25480 rows x 3 columns]

# %%
#slicing will not work
#question_ we want 100,200,300 no. row from 2,3,7 col
#instead of two take() we use loc() and iloc()
# visa_f.iloc[<row>,<col>]
# visa_f.iloc[start:stop:step,start:stop:step]
visa_f.iloc[[1,2,3],[2,3,7]]
# Out:
#   education_of_employee has_job_experience region_of_employment
# 1              Master's                  Y            Northeast
# 2            Bachelor's                  N                 West
# 3            Bachelor's                  N                 West

# %%
visa_f.iloc[1:5]
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 1         83425.65         Year                  Y   Certified
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied
# ...

# %%
visa_f.iloc[1:5,2:7]
# Out:
#   education_of_employee has_job_experience requires_job_training  \
# 1              Master's                  Y                     N
# 2            Bachelor's                  N                     Y
# 3            Bachelor's                  N                     N
# 4              Master's                  Y                     N
#
#    no_of_employees  yr_of_estab
# 1             2412         2002
# 2            44444         2008
# 3               98         1897
# 4             1082         2005

# %%
visa_f.iloc[lambda x: x.index % 2==0]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 2         EZYV03           Asia            Bachelor's                  N
# 4         EZYV05         Africa              Master's                  Y
# 6         EZYV07           Asia            Bachelor's                  N
# 8         EZYV09           Asia            Bachelor's                  N
# ...          ...            ...                   ...                ...
# 25470  EZYV25471  North America              Master's                  Y
# 25472  EZYV25473           Asia           High School                  N
# 25474  EZYV25475         Africa             Doctorate                  N
# 25476  EZYV25477           Asia           High School                  Y
# 25478  EZYV25479           Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_f.iloc[:,[True,True,True,False,False,False,False,False,False,False,False,False]]
# Out:
#          case_id continent education_of_employee
# 0         EZYV01      Asia           High School
# 1         EZYV02      Asia              Master's
# 2         EZYV03      Asia            Bachelor's
# 3         EZYV04      Asia            Bachelor's
# 4         EZYV05    Africa              Master's
# ...          ...       ...                   ...
# 25475  EZYV25476      Asia            Bachelor's
# 25476  EZYV25477      Asia           High School
# 25477  EZYV25478      Asia              Master's
# 25478  EZYV25479      Asia              Master's
# 25479  EZYV25480      Asia            Bachelor's
#
# [25480 rows x 3 columns]

# %%
visa_f.loc[:,['case_id','continent','education_of_employee']]
# Out:
#          case_id continent education_of_employee
# 0         EZYV01      Asia           High School
# 1         EZYV02      Asia              Master's
# 2         EZYV03      Asia            Bachelor's
# 3         EZYV04      Asia            Bachelor's
# 4         EZYV05    Africa              Master's
# ...          ...       ...                   ...
# 25475  EZYV25476      Asia            Bachelor's
# 25476  EZYV25477      Asia           High School
# 25477  EZYV25478      Asia              Master's
# 25478  EZYV25479      Asia              Master's
# 25479  EZYV25480      Asia            Bachelor's
#
# [25480 rows x 3 columns]

# %%
#session 3
