# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\debasish\\DS-AI\\N-IT'

# %% [markdown]
# **encoding**
#
# - encoding = cat to num
#
# - ml expects all data in num format
#
# -  ml models developed by math algos
#
# - the follows of encoding methods
#
#     - map
#
#     - np.where
#
#     - one hot encoding
#
#     - lable encoder

# %% [markdown]
# **Map**
#
# - method to connvert cat values to num values
#
# - take one cat col then get the unique labels first
#
# - make a dict with assign a number to each label
#
# - for ex case_status =
#
#   - certifies : 0
#
#   - denied : 1
#
# - dict = {'cerified' : 0, 'denied' : 1}

# %%
path=r"C:\Users\debasish\DS-AI\N-IT\datafiles\Visadataset.csv"


visa_df=pd.read_csv(path)
cat_column=visa_df.select_dtypes(include='object').columns
num_column=visa_df.select_dtypes(exclude='object').columns

# %%
visa_df['case_status'].unique()
dict = {'Certified' : 0, 'Denied' : 1} 
visa_df['case_status_new']=visa_df['case_status'].map(dict)
visa_df['case_status_new']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status_new, Length: 25480, dtype: int64

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_f=pd.DataFrame()
visa_f=pd.concat([visa_f,visa_df.drop('case_status_new',axis=1)],axis=1)
visa_f
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['case_status'].replace([0,1],['Certified','Denied'],inplace=True)

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
labels=visa_df['case_status'].unique()
list1=[i for i in range(len(labels))]
labels.sort()
list1
dict1={(i,j) for i,j in (zip(labels,list1))}
visa_df['case_status']=visa_df['case_status'].map(dict)

# %%
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0          NaN        NaN                    NaN                 NaN
# 1          NaN        NaN                    NaN                 NaN
# 2          NaN        NaN                    NaN                 NaN
# 3          NaN        NaN                    NaN                 NaN
# 4          NaN        NaN                    NaN                 NaN
# ...        ...        ...                    ...                 ...
# 25475      NaN        NaN                    NaN                 NaN
# 25476      NaN        NaN                    NaN                 NaN
# 25477      NaN        NaN                    NaN                 NaN
# 25478      NaN        NaN                    NaN                 NaN
# 25479      NaN        NaN                    NaN                 NaN
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                        NaN            14513         2007
# ...

# %%
path=r"C:\Users\debasish\DS-AI\N-IT\datafiles\Visadataset.csv"
visa_df=pd.read_csv(path)
print(visa_df)
cat=visa_df.select_dtypes(include='object')
# for i in cat.columns:
#     labels=visa_df[i].unique()
#     list1=[i for i in range(len(labels))]
#     dict2={(i,j) for i,j in (zip(labels,list1))}
#     visa_df[i]=visa_df[i].map(dict)
# print(cat.columns)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
dict2
# Out:
# {('Certified', 0), ('Denied', 1)}

# %%
dict1={(i,j) for i,j in (zip(labels.sort,list1))}
dict1
# Out:
# {(nan, 0)}

# %% [markdown]
# **Label Encoder**
#
# - LabelEncoder is a method to convert cat to num cols
#
# - labelEncoder does same as for loop map
#
# - it is under ** sickiy_learn** we usually called as **sklearn**
#
# - Under sklearn we haev class called as preporcesing
#
# - because currently we re doing data preprocessing only
#
# - under preprocessing class we have a method called as **LabelEncoder**
#
# - sklearn
#
#     - preprocessing
#
#         - labelEncoder
#
# - any sklearn package has 3 steps=
#
#     - read the package
#
#     - save the package
#
#     - aplly fit on data transform

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_f['case_status']=le.fit_transform(visa_f['case_status'])

# %%
visa_f
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
path=r"C:\Users\debasish\DS-AI\N-IT\datafiles\Visadataset.csv"
visa_f=pd.read_csv(path)

cat=visa_f.select_dtypes(include='object')
for i in cat.columns:
    visa_f[i]=le.fit_transform(visa_f[i])

# %%
visa_f
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **fit and transform **
#
# - fit means develop the logic
#
# - transform means process the logic
#
# - if we observe in map method first we develeoped dictionary logic
#
# - the we apply that dcitionary to column
#
# - developing the dictionary is kind of fit
#
# - apply the dict to col means we are transfroming the data cat to num
#
# - whenever we are tansforming or changing the data then we use fit transform
#
# - if we are not changing the data then only fit

# %% [markdown]
# ** np.where**
#
# - using np.where also we can change cat to num
#
# - but np.where is only for bianry conditions
#
# - it is same as if_else
#
# - a col should have only two unique labels

# %%
path=r"C:\Users\debasish\DS-AI\N-IT\datafiles\Visadataset.csv"
visa_f=pd.read_csv(path)

cat=visa_f.select_dtypes(include='object')

# %%
con=visa_f['case_status']=='Certified'
visa_f['case_status']=np.where(con,0,1)
visa_f
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ** one hot encoder**
#
# - one got means if one will be ON , another will be OFF
#
# - ON==> 1
#
# - OFF==> 0
#
# - for ex-
#
#     - case_status as labels
#
#         - Certified and Denied
#
# - one hot encoder crestes new columns which is equal to no. of unique labels
#
# - for example case status will create two new cols
#
#     - case_status_certified
#
#     - case_status_denied
#
# case_status|case_status_certified|case_status_denied
# |-|-|-|
# denied|0|1|
# certified|1|0|
