# %% [markdown]
# # # #csv comma separated value
# # .txt
# # .json
# # xlsx
# # .pdf
# # .doc .docx
# # .yaml
# # encoded
# # .xml
# # .mp3
# # .MP4
# # .jpg .png .jpeg
# # # #paequet .parquet
# # # tfrecords .tfrecods (tensorflow)

# %% [markdown]
# <!-- location,nm,extension -->

# %% [markdown]
# # loc - directory // C:\Users\debasish\DS-AI\N-IT\datafiles //C:\Users\debasish\DS-AI\N-IT\datafiles
# # nm- name of file
# # extension - type of file

# %%
r'C:\\\\Users\\debasish\\DS-AI\\N-IT\datafiles'
# Out:
# 'C:\\\\\\\\Users\\\\debasish\\\\DS-AI\\\\N-IT\\datafiles'

# %%
# #unicode error
# whenever we read the file it should be in quotes maa
# if we have single slash then we will get unicode error
#in order to avoid that we need to provide double slash 
#or we can provide a letter r at the starting of the path

# %%
fp=r'C:\Users\debasish\DS-AI\N-IT\datafiles\mbox-short.txt'
file=open(fp)
print(file.read())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %% [markdown]
# - whenever we open a file
# - file
# -mode {r,w,wr,rw etc}
# - encode
#  -encoding is used to avoid special characters
#   - by default cp1252
#   - if you want to avoid spl character= 'utf-8-sig'

# %%
fp=r'C:\Users\debasish\DS-AI\N-IT\datafiles\mbox-short.txt'
file=open(fp,mode='r',encoding='utf-8-sig' )
print(file.read())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %% [markdown]
# method 2
# - we can read the file without using folder
# - cause ever directory id different
# - different laps has different directory
# - to read keep data files in pyton folder

# %%
fo=r'chatbot.txt'
file=open(fo,mode='r',encoding='utf-8-sig')
data =file.read()
print(data)
# Out:
# Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from noisy, structured, and unstructured data.[2]
#
# Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\debasish\\DS-AI\\N-IT'

# %%
fo=r'chatbot.txt'
# file=open(fo,mode='r',encoding='utf-8-sig')
# data =file.read()
# print(data)

with open(fo) as pop:
    data = pop.read()
print(data)
# Out:
# Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from noisy, structured, and unstructured data.[2]
#
# Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]
#
# ...

# %%
file_n="dumm.txt"
with open(file_n,mode='w') as file:
    data=file.write("hello gdmrng")

# %%
file_n="dumm.txt"
with open(file_n,mode='w') as file:
    data=file.write("hello gdmrng")
    data=file.write("hello boi")
    data=file.write("hello mrng")

file_n="dumm.txt"
with open(file_n,mode='r') as file:
    for i in file:
        print(i)
# Out:
# hello gdmrnghello boihello mrng

# %%
fo=r'chatbot.txt'
file=open(fo,mode='r',encoding='utf-8-sig')
data =file.read()
print(data)

file_n="chatbot.txt"
with open(file_n,mode='r') as file:
    for i,_ in enumerate(file):
        pass
    print(i)
# Out:
# Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from noisy, structured, and unstructured data.[2]
#
# Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]
#
# ...

# %%
file_n="mbox-short.txt"
with open(file_n,mode='r') as file:
    c=0
    for i,e in enumerate(file):
        print(f'{i+1}-{e}')
        c+=1
        if c==10:
            break       
    print(f'{c}=lines')
# Out:
# 1-From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 2-Return-Path: <postmaster@collab.sakaiproject.org>
#
# 3-Received: from murder (mail.umich.edu [141.211.14.90])
#
# 4-	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 5-	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 6-X-Sieve: CMU Sieve 2.3
#
# 7-Received: from murder ([unix socket])
#
# 8-	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 9-	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 10-Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10=lines

# %%
file_n="mbox-short.txt"
with open(file_n,mode='r') as file:    
    x=[(f'{i}-{e}') for i,e in enumerate(file)]
    print((x))
# Out:
# ['0-From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\n', '1-Return-Path: <postmaster@collab.sakaiproject.org>\n', '2-Received: from murder (mail.umich.edu [141.211.14.90])\n', '3-\t by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;\n', '4-\t Sat, 05 Jan 2008 09:14:16 -0500\n', '5-X-Sieve: CMU Sieve 2.3\n', '6-Received: from murder ([unix socket])\n', '7-\t by mail.umich.edu (Cyrus v2.2.12) with LMTPA;\n', '8-\t Sat, 05 Jan 2008 09:14:16 -0500\n', '9-Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])\n', '10-\tby flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;\n', '11-\tSat, 5 Jan 2008 09:14:15 -0500\n', '12-Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])\n', '13-\tBY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ; \n', '14-\t 5 Jan 2008 09:14:10 -0500\n', '15-Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])\n', '16-\tby paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;\n', '17-\tSat,  5 Jan 
# ...

# %%
file_n="mbox-short.txt"
with open(file_n,mode='r') as file:    
    x=[print(i,e) for i,e in enumerate(file) if i<11]
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;

# %%
file_n="mbox-short.txt"
with open(file_n,mode='r') as file:    
    x=[print(i,e) for i,e in enumerate(file) if i<11]
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;

# %%
file_n="mbox-short.txt"
with open(file_n,mode='r') as file:   
    for i in file:
        print(i.strip())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# ...

# %%
file_n="mbox-short.txt"
with open(file_n,mode='r') as file:    
    x=[print(i,e.strip()) for i,e in enumerate(file) if 'From' in e]
    print(len(x))
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# 37 From: stephen.marquard@uct.ac.za
# 65 From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008
# 102 From: louis@media.berkeley.edu
# 130 From zqian@umich.edu Fri Jan  4 16:10:39 2008
# 167 From: zqian@umich.edu
# 194 From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008
# 231 From: rjlowe@iupui.edu
# 262 From zqian@umich.edu Fri Jan  4 15:03:18 2008
# 299 From: zqian@umich.edu
# 335 From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008
# 372 From: rjlowe@iupui.edu
# 414 From cwen@iupui.edu Fri Jan  4 11:37:30 2008
# 451 From: cwen@iupui.edu
# 493 From cwen@iupui.edu Fri Jan  4 11:35:08 2008
# 530 From: cwen@iupui.edu
# 572 From gsilver@umich.edu Fri Jan  4 11:12:37 2008
# 609 From: gsilver@umich.edu
# 638 From gsilver@umich.edu Fri Jan  4 11:11:52 2008
# 675 From: gsilver@umich.edu
# 704 From zqian@umich.edu Fri Jan  4 11:11:03 2008
# 741 From: zqian@umich.edu
# 769 From gsilver@umich.edu Fri Jan  4 11:10:22 2008
# ...

# %%
file_n="mbox-short.txt"
with open(file_n,mode='r') as file:    
    x=[(i.split()[1]) for i in file if i.startswith('From')]
x
# Out:
# ['stephen.marquard@uct.ac.za',
#  'stephen.marquard@uct.ac.za',
#  'louis@media.berkeley.edu',
#  'louis@media.berkeley.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'wagnermr@iupui.edu',
#  'wagnermr@iupui.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'antranig@caret.cam.ac.uk',
#  'antranig@caret.cam.ac.uk',
#  'gopal.ramasammycook@gmail.com',
#  'gopal.ramasammycook@gmail.com',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
# ...

# %%
file_n="mbox-short.txt"
with open(file_n,mode='r') as file:    
    x=[print(i,e.strip('\n')) for i,e in enumerate(file)]
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
# 3 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 4 	 Sat, 05 Jan 2008 09:14:16 -0500
# 5 X-Sieve: CMU Sieve 2.3
# 6 Received: from murder ([unix socket])
# 7 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 8 	 Sat, 05 Jan 2008 09:14:16 -0500
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 10 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 11 	Sat, 5 Jan 2008 09:14:15 -0500
# 12 Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 13 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 14 	 5 Jan 2008 09:14:10 -0500
# 15 Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 16 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 17 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# ...

# %%
file_n="mbox-short.txt"
with open(file_n,mode='r') as file:    
    x=[(i.split()[1]) for i in file if i.startswith('From')]
s=set(x)
s
# string=''.join(x)
# #print(string)
# print(string.split('.'))
# Out:
# {'antranig@caret.cam.ac.uk',
#  'cwen@iupui.edu',
#  'david.horwitz@uct.ac.za',
#  'gopal.ramasammycook@gmail.com',
#  'gsilver@umich.edu',
#  'louis@media.berkeley.edu',
#  'ray@media.berkeley.edu',
#  'rjlowe@iupui.edu',
#  'stephen.marquard@uct.ac.za',
#  'wagnermr@iupui.edu',
#  'zqian@umich.edu'}

# %%
file_n="mbox-short.txt"
with open(file_n,mode='r') as file:    
    x=[(i.split()[1]) for i in file if i.startswith('From')]
s=set(x)
st=str(s)
dot=st.split('.')
y=[print(e.split()) for e in dot if '@' in e]

    # email=str(s)
    # l,d=email.split('@')
# Out:
# ["{'gsilver@umich"]
# ['marquard@uct']
# ["za',", "'louis@media"]
# ["edu',", "'ray@media"]
# ["edu',", "'rjlowe@iupui"]
# ["edu',", "'cwen@iupui"]
# ["edu',", "'wagnermr@iupui"]
# ['horwitz@uct']
# ["za',", "'zqian@umich"]
# ["edu',", "'antranig@caret"]
# ['ramasammycook@gmail']
