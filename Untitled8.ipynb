# %%
import pandas as pd
import matplotlib.pyplot as plt
dict1={'a':['john','son','ron'],'b':[52,98,45]}
data=pd.DataFrame(dict1)
plt.bar('a','b',data=data)
# Out:
# <BarContainer object of 3 artists>
